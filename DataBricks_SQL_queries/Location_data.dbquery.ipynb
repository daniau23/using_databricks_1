-- %%
select * 
from emissions_data_2023

-- using specific columns
-- for strings use `` instead of "" or ''
SELECT latitude, longitude, `GHG emissions mtons CO2e` as emissons 
from emissions_data_2023
